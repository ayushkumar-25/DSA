# %% [markdown]
# <a href="https://colab.research.google.com/github/ayushkumar-25/DSA/blob/main/learn_the_basics/know_basic_maths.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Count all digits of a number
# [GeeksforGeeks](https://www.geeksforgeeks.org/problems/count-total-digits-in-a-number/1)

# %%
# Brute Force

num = abs(int(input('Enter number: ')))
count = 0

while num != 0:
  num = num // 10
  count += 1

print(count)
# Out:
# Enter number: -12345678
# 8

# %%
# Logrithmic Method

import math

num = abs(int(input('Enter Number: ')))

count = int(math.log10(num)) + 1
print(count)
# Out:
# Enter Number: 999
# 3

# %%
# Pythonic Way

num = int(input('Enter Number: '))
len_count = len(str(abs(num)))
print(len_count)
# Out:
# Enter Number: -156789
# 6

# %% [markdown]
# ## Reverse a number
#
# [LeetCode](https://leetcode.com/problems/reverse-integer/description/)

# %%
# Brute Force

num = int(input("Enter Number: "))
rev = 0

sign = -1 if num < 0 else 1
num = abs(num)

while num != 0:
  digit = num % 10
  rev = rev * 10 + digit
  num = num // 10

if rev <= -2**31 or rev >= 2**31 - 1:
  print(0)
else:
  print(rev * sign)
# Out:
# Enter Number: -12345678
# -87654321

# %% [markdown]
# ## Palindrome number
# [LeetCode](https://leetcode.com/problems/palindrome-number/description/)

# %%
# Brute Force

num = int(input("Enter Number: "))
dub = num
rev = 0

if num < 0:
  print(False)
elif num == 0:
  print(True)
else:
  while num != 0:
    digit = num % 10
    rev = rev * 10 + digit
    num = num // 10
  if rev == dub:
    print(True)
  else:
    print(False)
# Out:
# Enter Number: 10
# False

# %%
# Pythonic Way

num = int(input("Enter Number: "))
if str(num) == str(num)[::-1]:
  print(True)
else:
  print(False)
# Out:
# Enter Number: 121
# True

# %% [markdown]
# ## Check if the number is Armstrong
# [GeeksforGeeks](https://www.geeksforgeeks.org/problems/armstrong-numbers2727/1)

# %%
# Brute Force

num = int(input("Enter Number: "))

if num < 0:
  print("False")

else:
  temp = num
  sum = 0
  digits = len(str(num))

  # Check Armstrong
  while temp != 0:
    digit = temp % 10
    sum = sum + digit ** digits
    temp = temp // 10

  if sum == num:
    print("Yes")
  else:
    print("No")
# Out:
# Enter Number: 6
# Yes
